# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Data/fifa_players_22_cleaned.csv")
df
# Out:
#        Unnamed: 0               name player_positions best_position  overall  \
# 0               0           L. Messi       RW, ST, CF            RW       93
# 1               1     R. Lewandowski               ST            ST       92
# 2               2  Cristiano Ronaldo           ST, LW            ST       91
# 3               3          Neymar Jr          LW, CAM            LW       91
# 4               4       K. De Bruyne          CM, CAM            CM       91
# ...           ...                ...              ...           ...      ...
# 18999       19069           R. Mahon           LW, LM            ST       48
# 19000       19070           S. Black               CB            CB       48
# 19001       19071  H. Wiles-Richards               GK            GK       48
# 19002       19072         J. Affonso               CM           CAM       48
# 19003       19073          C. Mutawe               CB            CB       48
#
#        potential    value_eur  wage_eur  age         dob  ...  \
# 0             93   78000000.0  320000.0   34  1987-06-24  ...
# 1             92  119500000.0  270000.0   32  1988-08-21  ...
# 2             91   45000000.0  270000.0   36  1985-02-05  ...
# 3             91  129000000.0  270000.0   29  1992-02-05  ...
# 4             91  125500000.0  350000.0   30  1991-06-28  ...
# ...          ...          ...       ...  ...         ...  ...
# 18999         60     110000.0     500.0   18  2003-06-06  ...
# 19000         62     100000.0     500.0   19  2002-03-01  ...
# 19001         65     110000.0    1000.0   19  2002-05-27  ...
# 19002         55      90000.0     500.0   23  1998-06-09  ...
# 19003         58     100000.0     500.0   20  2001-06-25  ...
#
#        mentality_composure  defending_marking_awareness  \
# 0                       96                           20
# 1                       88                           35
# 2                       95                           24
# 3                       93                           35
# 4                       89                           68
# ...                    ...                          ...
# 18999                   47                           15
# 19000                   44                           50
# 19001                   23                            9
# 19002                   35                           39
# 19003                   41                           50
#
#       defending_standing_tackle defending_sliding_tackle  goalkeeping_diving  \
# 0                            35                       24                   6
# 1                            42                       19                  15
# 2                            32                       24                   7
# 3                            32                       29                   9
# 4                            65                       53                  15
# ...                         ...                      ...                 ...
# 18999                        24                       23                   7
# 19000                        49                       47                   5
# 19001                        12                       13                  52
# 19002                        42                       44                   8
# 19003                        55                       49                  13
#
#       goalkeeping_handling  goalkeeping_kicking goalkeeping_positioning  \
# 0                       11                   15                      14
# 1                        6                   12                       8
# 2                       11                   15                      14
# 3                        9                   15                      15
# 4                       13                    5                      10
# ...                    ...                  ...                     ...
# 18999                   14                    6                       8
# 19000                    6                    7                      13
# 19001                   49                   49                      43
# 19002                   11                   11                       9
# 19003                   15                   10                       8
#
#       goalkeeping_reflexes  goalkeeping_speed
# 0                        8                NaN
# 1                       10                NaN
# 2                       11                NaN
# 3                       11                NaN
# 4                       13                NaN
# ...                    ...                ...
# 18999                   15                NaN
# 19000                   10                NaN
# 19001                   48               33.0
# 19002                   10                NaN
# 19003                   13                NaN
#
# [19004 rows x 68 columns]

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.columns
# Out:
# Index(['name', 'player_positions', 'best_position', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'age', 'dob', 'height_cm', 'weight_kg',
#        'club_name', 'league_name', 'league_level', 'club_position',
#        'nationality_id', 'nationality_name', 'preferred_foot', 'weak_foot',
#        'skill_moves', 'international_reputation', 'work_rate', 'body_type',
#        'release_clause_eur', 'player_tags', 'player_traits', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# name                           0
# player_positions               0
# best_position                  0
# overall                        0
# potential                      0
#                            ...
# goalkeeping_handling           0
# goalkeeping_kicking            0
# goalkeeping_positioning        0
# goalkeeping_reflexes           0
# goalkeeping_speed          16910
# Length: 67, dtype: int64

# %%
# Player Overall Rating Distribution"
plt.figure(figsize=(15,7))
ax = sns.countplot(x='overall', data=df)
ax.set_title('Player Distribution by Overall Rating', fontsize=20)
ax.set_xlabel('Overall', fontsize=15)
ax.set_ylabel('Number of Player', fontsize=15)
plt.show()

# %% [markdown]
# The FIFA players' overall rating shows a normal distribution with majority of players fall within 60-73 rating.

# %% [markdown]
# Comparing the each player attribute to the overall rating. Some attributes show bimodal distribution due to the player position difference.

# %%
df.hist(bins=20, figsize=(25,20))
plt.show()

# %% [markdown]
# ### Attributes that are showing bimodal distribution

# %%
selected_stat = ['defending', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_crossing', 'skill_dribbling', 'skill_ball_control', 'mentality_interceptions', 'mentality_positioning', 'defending_standing_tackle', 'defending_sliding_tackle']

for i in selected_stat:
    df[i].hist(bins=20, figsize=(7,6), color='c')
    plt.xlabel(i)
    plt.ylabel('Num of Players')
    plt.show()

# %% [markdown]
# Grouping the field positions

# %%
# Separating data by positions (ATT, MID, DEF, GK)
pos_att = df[df['best_position'].isin(['CF', 'LW', 'RW', 'ST'])]
pos_mid = df[df['best_position'].isin(['CAM','CDM', 'CM', 'LM', 'RM'])]
pos_def = df[df['best_position'].isin(['CB', 'LB', 'LWB', 'RB', 'RWB'])]
pos_gk = df[df['best_position'].isin(['GK'])]

# Combining all positions except GK
all_pos_wo_gk = pd.concat([pos_att, pos_mid, pos_def])

# %% [markdown]
# Below plots show which positions are distributed based on specifict player attributes.
#
# Ex. The attacking positions show higher "finishing" rating vs. the defending positions.

# %%
# Plotting bimodal distribution
selected_stat = ['defending', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_crossing', 'skill_dribbling', 'skill_ball_control', 'mentality_interceptions', 'mentality_positioning', 'defending_standing_tackle', 'defending_sliding_tackle']

for i in selected_stat:
    sns.relplot(data=all_pos_wo_gk, x=i, y='overall', hue= 'best_position', palette='cubehelix')

# %%
sns.relplot(data=df, x='overall', y='value_eur', hue= 'best_position', palette='cubehelix')

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="overall",y="value_eur",data=df).set(title='Overall Score & Value')
plt.show()

# %%
# Player Position Distribution
plt.figure(figsize=(12,8))
pos=df['best_position'].value_counts()
pos.plot(kind='bar', fontsize=10, subplots=True, color='m')
plt.title("Player's Position Distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(10,10),dpi=200)
graph = sns.catplot(y="best_position", x="value_eur", kind="bar",  data=df)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x ='best_position', 
            y ='overall', 
            data = df, 
            palette ='cool'
           ).set_title('Player overall by position');

# %% [markdown]
# - All the GKs are missing the the player attributes (pace, shooting, passing, dribbling, defending) due to their position.
# - All the players, except GK, are missing the goalkeeping speed due to their positions.

# %%
df.corr()
# Out:
#                               overall  potential  value_eur  wage_eur  \
# overall                      1.000000   0.645636   0.559877  0.604627
# potential                    0.645636   1.000000   0.530965  0.499848
# value_eur                    0.559877   0.530965   1.000000  0.824668
# wage_eur                     0.604627   0.499848   0.824668  1.000000
# age                          0.448490  -0.275813   0.038462  0.153917
# height_cm                    0.039534   0.002301   0.010097  0.028719
# weight_kg                    0.144407  -0.021344   0.033645  0.065084
# league_level                -0.181072  -0.155582  -0.119342 -0.127278
# nationality_id              -0.165874  -0.245271  -0.083900 -0.092606
# weak_foot                    0.220440   0.156001   0.149855  0.159433
# skill_moves                  0.374718   0.285225   0.257919  0.270432
# international_reputation     0.471298   0.355878   0.632942  0.676390
# release_clause_eur           0.532613   0.510241   0.976863  0.794501
# pace                         0.178104   0.260005   0.183849  0.135800
# shooting                     0.484313   0.285139   0.290115  0.309869
# passing                      0.712245   0.437684   0.406964  0.438132
# dribbling                    0.663807   0.490477   0.406969  0.421183
# defending                    0.344961   0.161834   0.147643  0.178958
# physic                       0.524460   0.152454   0.214848  0.248760
# attacking_crossing           0.398741   0.243423   0.227535  0.251228
# attacking_finishing          0.335393   0.229777   0.217508  0.227549
# attacking_heading_accuracy   0.343100   0.193465   0.166145  0.206585
# attacking_short_passing      0.514821   0.367703   0.298355  0.323547
# attacking_volleys            0.377946   0.234685   0.238346  0.262404
# skill_dribbling              0.382913   0.312209   0.241601  0.253866
# skill_curve                  0.418516   0.270296   0.253065  0.279697
# skill_fk_accuracy            0.376775   0.206197   0.214249  0.243824
# skill_long_passing           0.495840   0.324963   0.279554  0.309640
# skill_ball_control           0.458430   0.347785   0.270768  0.292246
# movement_acceleration        0.195080   0.233567   0.158916  0.133782
# movement_sprint_speed        0.207581   0.236827   0.166036  0.143358
# movement_agility             0.269694   0.223478   0.177343  0.170130
# movement_reactions           0.871605   0.523611   0.496232  0.540913
# movement_balance             0.124795   0.138607   0.118423  0.104961
# power_shot_power             0.556557   0.329752   0.301704  0.342742
# power_jumping                0.282433   0.095003   0.117954  0.147484
# power_stamina                0.383403   0.198689   0.199007  0.198400
# power_strength               0.358265   0.069919   0.127704  0.160909
# power_long_shots             0.406466   0.241597   0.231204  0.255436
# mentality_aggression         0.398231   0.191311   0.183246  0.223928
# mentality_interceptions      0.315373   0.157556   0.141093  0.170035
# mentality_positioning        0.355928   0.232902   0.224239  0.238728
# mentality_vision             0.520459   0.345257   0.325351  0.345441
# mentality_penalties          0.339762   0.206542   0.195941  0.226521
# mentality_composure          0.707103   0.427752   0.391034  0.437105
# defending_marking_awareness  0.310122   0.161322   0.141090  0.168540
# defending_standing_tackle    0.258888   0.157120   0.120993  0.144285
# defending_sliding_tackle     0.232790   0.141510   0.103724  0.125530
# goalkeeping_diving          -0.012758  -0.045465  -0.022372 -0.023889
# goalkeeping_handling        -0.012148  -0.046767  -0.022587 -0.023838
# goalkeeping_kicking         -0.014822  -0.049492  -0.021748 -0.023948
# goalkeeping_positioning     -0.003933  -0.042185  -0.021301 -0.022400
# goalkeeping_reflexes        -0.009174  -0.044523  -0.020012 -0.022155
# goalkeeping_speed            0.492105   0.225851   0.203426  0.280501
#
#                                   age  height_cm  weight_kg  league_level  \
# overall                      0.448490   0.039534   0.144407     -0.181072
# potential                   -0.275813   0.002301  -0.021344     -0.155582
# value_eur                    0.038462   0.010097   0.033645     -0.119342
# wage_eur                     0.153917   0.028719   0.065084     -0.127278
# age                          1.000000   0.081212   0.237077     -0.052328
# height_cm                    0.081212   1.000000   0.765849      0.067365
# weight_kg                    0.237077   0.765849   1.000000      0.015237
# league_level                -0.052328   0.067365   0.015237      1.000000
# nationality_id               0.063626  -0.154578  -0.122572     -0.263384
# weak_foot                    0.076525  -0.158098  -0.117093     -0.014400
# skill_moves                  0.065727  -0.410815  -0.338419     -0.061495
# international_reputation     0.229127   0.042634   0.087122     -0.103725
# release_clause_eur           0.033402   0.008649   0.029260     -0.115523
# pace                        -0.206820  -0.399177  -0.360122     -0.012988
# shooting                     0.241142  -0.191159  -0.090434     -0.077827
# passing                      0.337927  -0.263765  -0.160605     -0.141238
# dribbling                    0.192835  -0.360967  -0.256194     -0.117150
# defending                    0.245281   0.196329   0.194809     -0.058860
# physic                       0.440576   0.500359   0.585183     -0.020329
# attacking_crossing           0.125794  -0.491567  -0.398955     -0.061310
# attacking_finishing          0.081960  -0.373739  -0.292214     -0.037772
# attacking_heading_accuracy   0.149933   0.009178   0.038591     -0.039687
# attacking_short_passing      0.139734  -0.344812  -0.269766     -0.089862
# attacking_volleys            0.140829  -0.343771  -0.257218     -0.053063
# skill_dribbling              0.023402  -0.477481  -0.399669     -0.051196
# skill_curve                  0.143972  -0.440254  -0.350320     -0.060173
# skill_fk_accuracy            0.183749  -0.412848  -0.320258     -0.053877
# skill_long_passing           0.184769  -0.317093  -0.245707     -0.091275
# skill_ball_control           0.084015  -0.401618  -0.327313     -0.070313
# movement_acceleration       -0.148540  -0.544990  -0.484998     -0.001924
# movement_sprint_speed       -0.140292  -0.451203  -0.400704     -0.002760
# movement_agility            -0.012359  -0.621662  -0.536363      0.001414
# movement_reactions           0.444468   0.005571   0.102639     -0.145378
# movement_balance            -0.068941  -0.769695  -0.652817      0.006039
# power_shot_power             0.271763  -0.159121  -0.053187     -0.090220
# power_jumping                0.219437   0.014656   0.077376      0.012976
# power_stamina                0.130295  -0.287631  -0.222393     -0.003948
# power_strength               0.343627   0.531963   0.610749     -0.002027
# power_long_shots             0.158397  -0.381376  -0.283296     -0.050892
# mentality_aggression         0.236577  -0.063224   0.004077     -0.045286
# mentality_interceptions      0.176646  -0.080697  -0.058226     -0.045991
# mentality_positioning        0.094599  -0.440084  -0.350940     -0.050922
# mentality_vision             0.200989  -0.358733  -0.274575     -0.087272
# mentality_penalties          0.144382  -0.320476  -0.235606     -0.042077
# mentality_composure          0.348128  -0.163133  -0.069821     -0.102207
# defending_marking_awareness  0.159619  -0.089927  -0.065908     -0.035672
# defending_standing_tackle    0.099332  -0.096892  -0.083892     -0.034957
# defending_sliding_tackle     0.087435  -0.097327  -0.086449     -0.033411
# goalkeeping_diving           0.110693   0.369848   0.342638     -0.013818
# goalkeeping_handling         0.113854   0.367396   0.340869     -0.011441
# goalkeeping_kicking          0.113217   0.365582   0.340755     -0.016117
# goalkeeping_positioning      0.121610   0.367117   0.343916     -0.014380
# goalkeeping_reflexes         0.112969   0.367451   0.342982     -0.014518
# goalkeeping_speed            0.394134  -0.044138   0.062402      0.002600
#
#                              nationality_id  weak_foot  ...  \
# overall                           -0.165874   0.220440  ...
# potential                         -0.245271   0.156001  ...
# value_eur                         -0.083900   0.149855  ...
# wage_eur                          -0.092606   0.159433  ...
# age                                0.063626   0.076525  ...
# height_cm                         -0.154578  -0.158098  ...
# weight_kg                         -0.122572  -0.117093  ...
# league_level                      -0.263384  -0.014400  ...
# nationality_id                     1.000000   0.013370  ...
# weak_foot                          0.013370   1.000000  ...
# skill_moves                       -0.019561   0.341736  ...
# international_reputation          -0.074592   0.135760  ...
# release_clause_eur                -0.081012   0.141458  ...
# pace                               0.039959   0.145232  ...
# shooting                          -0.070393   0.320845  ...
# passing                           -0.110978   0.280398  ...
# dribbling                         -0.090277   0.311274  ...
# defending                         -0.073966  -0.112804  ...
# physic                            -0.055174   0.018805  ...
# attacking_crossing                -0.037805   0.300023  ...
# attacking_finishing               -0.033596   0.365139  ...
# attacking_heading_accuracy        -0.052143   0.196004  ...
# attacking_short_passing           -0.074043   0.320424  ...
# attacking_volleys                 -0.040026   0.362180  ...
# skill_dribbling                   -0.035327   0.350169  ...
# skill_curve                       -0.050381   0.345380  ...
# skill_fk_accuracy                 -0.045813   0.329170  ...
# skill_long_passing                -0.061778   0.287748  ...
# skill_ball_control                -0.062500   0.345889  ...
# movement_acceleration              0.031447   0.262510  ...
# movement_sprint_speed              0.030931   0.251032  ...
# movement_agility                   0.026135   0.307896  ...
# movement_reactions                -0.141441   0.213418  ...
# movement_balance                   0.048930   0.251123  ...
# power_shot_power                  -0.094777   0.316553  ...
# power_jumping                      0.011445   0.082525  ...
# power_stamina                     -0.008883   0.239518  ...
# power_strength                    -0.043620   0.025400  ...
# power_long_shots                  -0.039086   0.363533  ...
# mentality_aggression              -0.043316   0.145850  ...
# mentality_interceptions           -0.045679   0.049803  ...
# mentality_positioning             -0.011395   0.349661  ...
# mentality_vision                  -0.050749   0.339575  ...
# mentality_penalties               -0.047715   0.340183  ...
# mentality_composure               -0.112137   0.305857  ...
# defending_marking_awareness       -0.043993   0.064098  ...
# defending_standing_tackle         -0.045254   0.039157  ...
# defending_sliding_tackle          -0.042581   0.021229  ...
# goalkeeping_diving                -0.020683  -0.219467  ...
# goalkeeping_handling              -0.023281  -0.220224  ...
# goalkeeping_kicking               -0.020723  -0.213938  ...
# goalkeeping_positioning           -0.022984  -0.217353  ...
# goalkeeping_reflexes              -0.021660  -0.220907  ...
# goalkeeping_speed                 -0.037797   0.135485  ...
#
#                              mentality_composure  defending_marking_awareness  \
# overall                                 0.707103                     0.310122
# potential                               0.427752                     0.161322
# value_eur                               0.391034                     0.141090
# wage_eur                                0.437105                     0.168540
# age                                     0.348128                     0.159619
# height_cm                              -0.163133                    -0.089927
# weight_kg                              -0.069821                    -0.065908
# league_level                           -0.102207                    -0.035672
# nationality_id                         -0.112137                    -0.043993
# weak_foot                               0.305857                     0.064098
# skill_moves                             0.603930                     0.231085
# international_reputation                0.356885                     0.115792
# release_clause_eur                      0.368539                     0.135080
# pace                                    0.095120                    -0.280772
# shooting                                0.558213                    -0.395236
# passing                                 0.718836                     0.181326
# dribbling                               0.672470                    -0.111689
# defending                               0.218988                     0.967660
# physic                                  0.403142                     0.506474
# attacking_crossing                      0.624916                     0.464232
# attacking_finishing                     0.604881                     0.053440
# attacking_heading_accuracy              0.567560                     0.589940
# attacking_short_passing                 0.757459                     0.600778
# attacking_volleys                       0.647328                     0.128662
# skill_dribbling                         0.680831                     0.374117
# skill_curve                             0.678759                     0.318948
# skill_fk_accuracy                       0.625720                     0.318543
# skill_long_passing                      0.703768                     0.631956
# skill_ball_control                      0.742532                     0.488676
# movement_acceleration                   0.418739                     0.224894
# movement_sprint_speed                   0.416867                     0.242505
# movement_agility                        0.506527                     0.204853
# movement_reactions                      0.696602                     0.332881
# movement_balance                        0.386292                     0.217302
# power_shot_power                        0.634113                     0.053398
# power_jumping                           0.283432                     0.330674
# power_stamina                           0.589212                     0.622274
# power_strength                          0.297159                     0.338539
# power_long_shots                        0.671913                     0.218492
# mentality_aggression                    0.566645                     0.754283
# mentality_interceptions                 0.427272                     0.937332
# mentality_positioning                   0.651797                     0.236504
# mentality_vision                        0.680856                     0.198911
# mentality_penalties                     0.620126                     0.165102
# mentality_composure                     1.000000                     0.441730
# defending_marking_awareness             0.441730                     1.000000
# defending_standing_tackle               0.393501                     0.939934
# defending_sliding_tackle                0.358329                     0.933113
# goalkeeping_diving                     -0.451199                    -0.553622
# goalkeeping_handling                   -0.448048                    -0.553555
# goalkeeping_kicking                    -0.447145                    -0.553314
# goalkeeping_positioning                -0.442554                    -0.551187
# goalkeeping_reflexes                   -0.448481                    -0.554663
# goalkeeping_speed                       0.470635                     0.395489
#
#                              defending_standing_tackle  \
# overall                                       0.258888
# potential                                     0.157120
# value_eur                                     0.120993
# wage_eur                                      0.144285
# age                                           0.099332
# height_cm                                    -0.096892
# weight_kg                                    -0.083892
# league_level                                 -0.034957
# nationality_id                               -0.045254
# weak_foot                                     0.039157
# skill_moves                                   0.209475
# international_reputation                      0.092562
# release_clause_eur                            0.118024
# pace                                         -0.283869
# shooting                                     -0.433859
# passing                                       0.156782
# dribbling                                    -0.143392
# defending                                     0.977986
# physic                                        0.468720
# attacking_crossing                            0.451532
# attacking_finishing                           0.022976
# attacking_heading_accuracy                    0.565446
# attacking_short_passing                       0.581838
# attacking_volleys                             0.095116
# skill_dribbling                               0.355757
# skill_curve                                   0.295272
# skill_fk_accuracy                             0.302220
# skill_long_passing                            0.620803
# skill_ball_control                            0.464324
# movement_acceleration                         0.212781
# movement_sprint_speed                         0.228054
# movement_agility                              0.182451
# movement_reactions                            0.280314
# movement_balance                              0.210341
# power_shot_power                              0.013901
# power_jumping                                 0.300772
# power_stamina                                 0.599926
# power_strength                                0.306565
# power_long_shots                              0.189975
# mentality_aggression                          0.748502
# mentality_interceptions                       0.951944
# mentality_positioning                         0.211021
# mentality_vision                              0.169762
# mentality_penalties                           0.130574
# mentality_composure                           0.393501
# defending_marking_awareness                   0.939934
# defending_standing_tackle                     1.000000
# defending_sliding_tackle                      0.977384
# goalkeeping_diving                           -0.552090
# goalkeeping_handling                         -0.551794
# goalkeeping_kicking                          -0.552213
# goalkeeping_positioning                      -0.550521
# goalkeeping_reflexes                         -0.553270
# goalkeeping_speed                             0.291689
#
#                              defending_sliding_tackle  goalkeeping_diving  \
# overall                                      0.232790           -0.012758
# potential                                    0.141510           -0.045465
# value_eur                                    0.103724           -0.022372
# wage_eur                                     0.125530           -0.023889
# age                                          0.087435            0.110693
# height_cm                                   -0.097327            0.369848
# weight_kg                                   -0.086449            0.342638
# league_level                                -0.033411           -0.013818
# nationality_id                              -0.042581           -0.020683
# weak_foot                                    0.021229           -0.219467
# skill_moves                                  0.174694           -0.604582
# international_reputation                     0.077945            0.012385
# release_clause_eur                           0.101574           -0.017278
# pace                                        -0.274525           -0.026009
# shooting                                    -0.469557            0.020266
# passing                                      0.122823            0.030188
# dribbling                                   -0.170034            0.010069
# defending                                    0.963921            0.031546
# physic                                       0.441504            0.048281
# attacking_crossing                           0.431109           -0.678803
# attacking_finishing                         -0.017654           -0.605578
# attacking_heading_accuracy                   0.544051           -0.749554
# attacking_short_passing                      0.547795           -0.745860
# attacking_volleys                            0.055647           -0.603517
# skill_dribbling                              0.325978           -0.775477
# skill_curve                                  0.263360           -0.617659
# skill_fk_accuracy                            0.268230           -0.563794
# skill_long_passing                           0.594190           -0.607481
# skill_ball_control                           0.429899           -0.805532
# movement_acceleration                        0.201221           -0.630874
# movement_sprint_speed                        0.216662           -0.634491
# movement_agility                             0.164135           -0.558289
# movement_reactions                           0.250811           -0.080802
# movement_balance                             0.200140           -0.533120
# power_shot_power                            -0.020128           -0.276567
# power_jumping                                0.301171           -0.211953
# power_stamina                                0.573951           -0.709895
# power_strength                               0.288989           -0.122293
# power_long_shots                             0.149540           -0.618623
# mentality_aggression                         0.730374           -0.599392
# mentality_interceptions                      0.940953           -0.509827
# mentality_positioning                        0.174972           -0.701625
# mentality_vision                             0.133973           -0.363963
# mentality_penalties                          0.094120           -0.629710
# mentality_composure                          0.358329           -0.451199
# defending_marking_awareness                  0.933113           -0.553622
# defending_standing_tackle                    0.977384           -0.552090
# defending_sliding_tackle                     1.000000           -0.531923
# goalkeeping_diving                          -0.531923            1.000000
# goalkeeping_handling                        -0.531749            0.971535
# goalkeeping_kicking                         -0.531793            0.968358
# goalkeeping_positioning                     -0.530231            0.971172
# goalkeeping_reflexes                        -0.532768            0.973859
# goalkeeping_speed                            0.306283            0.470474
#
#                              goalkeeping_handling  goalkeeping_kicking  \
# overall                                 -0.012148            -0.014822
# potential                               -0.046767            -0.049492
# value_eur                               -0.022587            -0.021748
# wage_eur                                -0.023838            -0.023948
# age                                      0.113854             0.113217
# height_cm                                0.367396             0.365582
# weight_kg                                0.340869             0.340755
# league_level                            -0.011441            -0.016117
# nationality_id                          -0.023281            -0.020723
# weak_foot                               -0.220224            -0.213938
# skill_moves                             -0.602427            -0.600848
# international_reputation                 0.013155             0.011968
# release_clause_eur                      -0.017238            -0.017130
# pace                                    -0.015280            -0.008989
# shooting                                 0.028915             0.045015
# passing                                  0.044863             0.041553
# dribbling                                0.021736             0.030709
# defending                                0.027663             0.020613
# physic                                   0.049567             0.060022
# attacking_crossing                      -0.676554            -0.676587
# attacking_finishing                     -0.603803            -0.600844
# attacking_heading_accuracy              -0.749257            -0.746212
# attacking_short_passing                 -0.743522            -0.740795
# attacking_volleys                       -0.601492            -0.598421
# skill_dribbling                         -0.773630            -0.771097
# skill_curve                             -0.615241            -0.613204
# skill_fk_accuracy                       -0.562147            -0.559788
# skill_long_passing                      -0.605494            -0.602163
# skill_ball_control                      -0.803733            -0.800518
# movement_acceleration                   -0.630852            -0.628713
# movement_sprint_speed                   -0.634382            -0.632112
# movement_agility                        -0.557924            -0.555526
# movement_reactions                      -0.080945            -0.082421
# movement_balance                        -0.532179            -0.530115
# power_shot_power                        -0.275415            -0.267413
# power_jumping                           -0.211533            -0.211089
# power_stamina                           -0.707800            -0.705465
# power_strength                          -0.123688            -0.121935
# power_long_shots                        -0.616457            -0.613255
# mentality_aggression                    -0.597600            -0.596423
# mentality_interceptions                 -0.509250            -0.509536
# mentality_positioning                   -0.699607            -0.696346
# mentality_vision                        -0.360145            -0.357973
# mentality_penalties                     -0.628811            -0.624392
# mentality_composure                     -0.448048            -0.447145
# defending_marking_awareness             -0.553555            -0.553314
# defending_standing_tackle               -0.551794            -0.552213
# defending_sliding_tackle                -0.531749            -0.531793
# goalkeeping_diving                       0.971535             0.968358
# goalkeeping_handling                     1.000000             0.967962
# goalkeeping_kicking                      0.967962             1.000000
# goalkeeping_positioning                  0.970670             0.967188
# goalkeeping_reflexes                     0.971765             0.968616
# goalkeeping_speed                        0.415897             0.419797
#
#                              goalkeeping_positioning  goalkeeping_reflexes  \
# overall                                    -0.003933             -0.009174
# potential                                  -0.042185             -0.044523
# value_eur                                  -0.021301             -0.020012
# wage_eur                                   -0.022400             -0.022155
# age                                         0.121610              0.112969
# height_cm                                   0.367117              0.367451
# weight_kg                                   0.343916              0.342982
# league_level                               -0.014380             -0.014518
# nationality_id                             -0.022984             -0.021660
# weak_foot                                  -0.217353             -0.220907
# skill_moves                                -0.601146             -0.602633
# international_reputation                    0.015502              0.014671
# release_clause_eur                         -0.016530             -0.014794
# pace                                       -0.028846             -0.018367
# shooting                                    0.032877              0.038679
# passing                                     0.038061              0.038395
# dribbling                                   0.020292              0.026708
# defending                                   0.022526              0.020136
# physic                                      0.052280              0.050753
# attacking_crossing                         -0.675255             -0.677933
# attacking_finishing                        -0.600688             -0.602562
# attacking_heading_accuracy                 -0.745004             -0.749073
# attacking_short_passing                    -0.740210             -0.743958
# attacking_volleys                          -0.598403             -0.601410
# skill_dribbling                            -0.769879             -0.772813
# skill_curve                                -0.613965             -0.615924
# skill_fk_accuracy                          -0.560332             -0.563003
# skill_long_passing                         -0.603130             -0.606889
# skill_ball_control                         -0.799927             -0.803664
# movement_acceleration                      -0.627433             -0.629111
# movement_sprint_speed                      -0.630276             -0.632356
# movement_agility                           -0.555472             -0.557273
# movement_reactions                         -0.073905             -0.076556
# movement_balance                           -0.528805             -0.531264
# power_shot_power                           -0.271545             -0.274166
# power_jumping                              -0.207197             -0.211456
# power_stamina                              -0.705961             -0.708657
# power_strength                             -0.118407             -0.121641
# power_long_shots                           -0.612901             -0.616295
# mentality_aggression                       -0.594894             -0.598485
# mentality_interceptions                    -0.507552             -0.510950
# mentality_positioning                      -0.695692             -0.698345
# mentality_vision                           -0.356356             -0.361180
# mentality_penalties                        -0.624652             -0.628037
# mentality_composure                        -0.442554             -0.448481
# defending_marking_awareness                -0.551187             -0.554663
# defending_standing_tackle                  -0.550521             -0.553270
# defending_sliding_tackle                   -0.530231             -0.532768
# goalkeeping_diving                          0.971172              0.973859
# goalkeeping_handling                        0.970670              0.971765
# goalkeeping_kicking                         0.967188              0.968616
# goalkeeping_positioning                     1.000000              0.971393
# goalkeeping_reflexes                        0.971393              1.000000
# goalkeeping_speed                           0.444558              0.470671
#
#                              goalkeeping_speed
# overall                               0.492105
# potential                             0.225851
# value_eur                             0.203426
# wage_eur                              0.280501
# age                                   0.394134
# height_cm                            -0.044138
# weight_kg                             0.062402
# league_level                          0.002600
# nationality_id                       -0.037797
# weak_foot                             0.135485
# skill_moves                                NaN
# international_reputation              0.216593
# release_clause_eur                    0.189207
# pace                                       NaN
# shooting                                   NaN
# passing                                    NaN
# dribbling                                  NaN
# defending                                  NaN
# physic                                     NaN
# attacking_crossing                    0.310975
# attacking_finishing                   0.489221
# attacking_heading_accuracy            0.233631
# attacking_short_passing               0.369659
# attacking_volleys                     0.465974
# skill_dribbling                       0.447642
# skill_curve                           0.289765
# skill_fk_accuracy                     0.267243
# skill_long_passing                    0.295920
# skill_ball_control                    0.441556
# movement_acceleration                 0.973654
# movement_sprint_speed                 0.938412
# movement_agility                      0.608523
# movement_reactions                    0.522739
# movement_balance                      0.454969
# power_shot_power                      0.419422
# power_jumping                         0.506944
# power_stamina                         0.553390
# power_strength                        0.286550
# power_long_shots                      0.497414
# mentality_aggression                  0.254732
# mentality_interceptions               0.527715
# mentality_positioning                 0.513933
# mentality_vision                      0.251358
# mentality_penalties                   0.410524
# mentality_composure                   0.470635
# defending_marking_awareness           0.395489
# defending_standing_tackle             0.291689
# defending_sliding_tackle              0.306283
# goalkeeping_diving                    0.470474
# goalkeeping_handling                  0.415897
# goalkeeping_kicking                   0.419797
# goalkeeping_positioning               0.444558
# goalkeeping_reflexes                  0.470671
# goalkeeping_speed                     1.000000
#
# [54 rows x 54 columns]

# %%
df.columns
# Out:
# Index(['name', 'player_positions', 'best_position', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'age', 'dob', 'height_cm', 'weight_kg',
#        'club_name', 'league_name', 'league_level', 'club_position',
#        'nationality_id', 'nationality_name', 'preferred_foot', 'weak_foot',
#        'skill_moves', 'international_reputation', 'work_rate', 'body_type',
#        'release_clause_eur', 'player_tags', 'player_traits', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed'],
#       dtype='object')

# %% [markdown]
# ## Selecting Features

# %%
# Selecting player features
player_df = df[['overall', 'potential', 'age', 'height_cm', 'weight_kg', 'weak_foot',
       'skill_moves', 'international_reputation',
       'attacking_crossing', 'attacking_finishing','attacking_heading_accuracy', 
       'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'goalkeeping_reflexes']]

player_df
# Out:
#        overall  potential  age  height_cm  weight_kg  weak_foot  skill_moves  \
# 0           93         93   34        170         72          4            4
# 1           92         92   32        185         81          4            4
# 2           91         91   36        187         83          4            5
# 3           91         91   29        175         68          5            5
# 4           91         91   30        181         70          5            4
# ...        ...        ...  ...        ...        ...        ...          ...
# 18999       48         60   18        168         58          3            2
# 19000       48         62   19        180         75          3            2
# 19001       48         65   19        180         72          2            1
# 19002       48         55   23        172         72          3            2
# 19003       48         58   20        184         60          3            2
#
#        international_reputation  attacking_crossing  attacking_finishing  ...  \
# 0                             5                  85                   95  ...
# 1                             5                  71                   95  ...
# 2                             5                  87                   95  ...
# 3                             5                  85                   83  ...
# 4                             4                  94                   82  ...
# ...                         ...                 ...                  ...  ...
# 18999                         1                  40                   52  ...
# 19000                         1                  28                   23  ...
# 19001                         1                  12                    5  ...
# 19002                         1                  40                   29  ...
# 19003                         1                  27                   19  ...
#
#        mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                       75                   96                           20
# 1                       90                   88                           35
# 2                       88                   95                           24
# 3                       93                   93                           35
# 4                       83                   89                           68
# ...                    ...                  ...                          ...
# 18999                   46                   47                           15
# 19000                   37                   44                           50
# 19001                   16                   23                            9
# 19002                   35                   35                           39
# 19003                   34                   41                           50
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             35                        24
# 1                             42                        19
# 2                             32                        24
# 3                             32                        29
# 4                             65                        53
# ...                          ...                       ...
# 18999                         24                        23
# 19000                         49                        47
# 19001                         12                        13
# 19002                         42                        44
# 19003                         55                        49
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                       6                    11                   15
# 1                      15                     6                   12
# 2                       7                    11                   15
# 3                       9                     9                   15
# 4                      15                    13                    5
# ...                   ...                   ...                  ...
# 18999                   7                    14                    6
# 19000                   5                     6                    7
# 19001                  52                    49                   49
# 19002                   8                    11                   11
# 19003                  13                    15                   10
#
#        goalkeeping_positioning  goalkeeping_reflexes
# 0                           14                     8
# 1                            8                    10
# 2                           14                    11
# 3                           15                    11
# 4                           10                    13
# ...                        ...                   ...
# 18999                        8                    15
# 19000                       13                    10
# 19001                       43                    48
# 19002                        9                    10
# 19003                        8                    13
#
# [19004 rows x 42 columns]

# %%
# features left out - 'best_position', 'value_eur', 'work_rate', 'body_type'

# %%
fig, ax = plt.subplots(figsize=(25,25))
sns.heatmap(player_df.corr(), linewidths=0.5, annot=True)
plt.show()
plt.clf()

# %% [markdown]
# Selected features show low pvalue, thus these features are statistically significant.

# %%
from scipy import stats

corr_df = pd.DataFrame(columns=['r', 'p_val'])

for col in player_df:
    r, p_val = stats.pearsonr(player_df.overall, df[col])
    corr_df.loc[col] = [r, p_val]

corr_df
# Out:
#                                     r          p_val
# overall                      1.000000   0.000000e+00
# potential                    0.645636   0.000000e+00
# age                          0.448490   0.000000e+00
# height_cm                    0.039534   4.988460e-08
# weight_kg                    0.144407   4.433498e-89
# weak_foot                    0.220440  7.497145e-208
# skill_moves                  0.374718   0.000000e+00
# international_reputation     0.471298   0.000000e+00
# attacking_crossing           0.398741   0.000000e+00
# attacking_finishing          0.335393   0.000000e+00
# attacking_heading_accuracy   0.343100   0.000000e+00
# attacking_short_passing      0.514821   0.000000e+00
# attacking_volleys            0.377946   0.000000e+00
# skill_dribbling              0.382913   0.000000e+00
# skill_curve                  0.418516   0.000000e+00
# skill_fk_accuracy            0.376775   0.000000e+00
# skill_long_passing           0.495840   0.000000e+00
# skill_ball_control           0.458430   0.000000e+00
# movement_acceleration        0.195080  2.383668e-162
# movement_sprint_speed        0.207581  5.021178e-184
# movement_agility             0.269694  5.446568e-314
# movement_reactions           0.871605   0.000000e+00
# movement_balance             0.124795   7.901574e-67
# power_shot_power             0.556557   0.000000e+00
# power_jumping                0.282433   0.000000e+00
# power_stamina                0.383403   0.000000e+00
# power_strength               0.358265   0.000000e+00
# power_long_shots             0.406466   0.000000e+00
# mentality_aggression         0.398231   0.000000e+00
# mentality_interceptions      0.315373   0.000000e+00
# mentality_positioning        0.355928   0.000000e+00
# mentality_vision             0.520459   0.000000e+00
# mentality_penalties          0.339762   0.000000e+00
# mentality_composure          0.707103   0.000000e+00
# defending_marking_awareness  0.310122   0.000000e+00
# defending_standing_tackle    0.258888  1.236839e-288
# defending_sliding_tackle     0.232790  3.187082e-232
# goalkeeping_diving          -0.012758   7.863727e-02
# goalkeeping_handling        -0.012148   9.401891e-02
# goalkeeping_kicking         -0.014822   4.101968e-02
# goalkeeping_positioning     -0.003933   5.876853e-01
# goalkeeping_reflexes        -0.009174   2.060162e-01

# %%
# Top 10 attributes with high correlation to overall
corr_df.sort_values('r', ascending=False)[1:11]
# Out:
#                                  r  p_val
# movement_reactions        0.871605    0.0
# mentality_composure       0.707103    0.0
# potential                 0.645636    0.0
# power_shot_power          0.556557    0.0
# mentality_vision          0.520459    0.0
# attacking_short_passing   0.514821    0.0
# skill_long_passing        0.495840    0.0
# international_reputation  0.471298    0.0
# skill_ball_control        0.458430    0.0
# age                       0.448490    0.0

# %%
# Saving the cleaned data for modeling
player_df.to_csv("fifa_players_data_for_models.csv")

# %% [markdown]
# ### Top 5 skill attributes

# %%
top5 = ['movement_reactions', 'mentality_composure', 'power_shot_power', 'mentality_vision', 'attacking_short_passing']

for i in top5:
    df[i].hist(bins=20, figsize=(7,6), color='y')
    plt.xlabel(i)
    plt.ylabel('Num of Players')
    plt.show()

# %%
top5 = ['movement_reactions', 'mentality_composure', 'power_shot_power', 'mentality_vision', 'attacking_short_passing']

for i in top5:
    sns.relplot(data=all_pos_wo_gk, x=i, y='overall', hue= 'best_position', palette='cubehelix')
